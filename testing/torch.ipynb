# %%
import torch

a = torch.tensor([1., 2., 3.])
b = torch.tensor([4., 5., 6.])

b2 = b.transpose(0, 0)  # Transpose has no effect on 1D tensor
b2

y = torch.matmul(a, b)
print(y)
# Out:
# tensor(32.)
